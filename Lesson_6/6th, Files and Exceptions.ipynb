# %% [markdown]
# ### Pattern Matching, Regular Expressions

# %%
import re
pattern = r"spam"

if re.match(pattern, "spamspamspam"): # match finds whether it matches at the \
                                      # beginning of a string 
   print("Match")
else:
   print("No match")

if re.match(pattern, "4spamspamspam"):
  print("Match")
else:
   print("No match")
# Out:
# Match
# No match

# %%
pattern = r"spam"

if re.match(pattern, "eggspamsausagespam"):
   print("Match")
else:
   print("No match")

if re.search(pattern, "eggspamsausagespam"):
   print("Match")
else:
   print("No match")
    
print(re.findall(pattern, "eggspamsausagespam"))
#re.search(pattern, "eggspamsausagespam")
# Out:
# No match
# Match
# ['spam', 'spam']
# <_sre.SRE_Match object; span=(3, 7), match='spam'>

# %%
pattern = r"pam"

match = re.search(pattern, "eggspamsausage") # returns an object
if match:
   print(match.group()) # pattern that matches
   print(match.start()) # index of first letter of pattern
   print(match.end())   # index of last letter of pattern
   print(match.span())
# Out:
# pam
# 4
# 7
# (4, 7)

# %%
text = "My name is David. Hi David."
pattern = r"David"
newstr = re.sub(pattern, "Amy", text)
print(newstr)
# Out:
# My name is Amy. Hi Amy.

# %% [markdown]
# #### Metacharacter

# %% [markdown]
# Metacharacters are what make regular expressions more powerful than normal string methods.

# %%
# .(dot) matches any character, other than a new line.
pattern = r"gr.y"

if re.match(pattern, "grey"):
   print("Match 1")

if re.match(pattern, "gray"):
   print("Match 2")

if re.match(pattern, "blue"):
   print("Match 3")
# Out:
# Match 1
# Match 2

# %%
#^, $ match the start and end of a string, respectively.
pattern = r"^(g)r.y$"

if re.match(pattern, "grey"):
   print("Match 1")

if re.match(pattern, "gray"):
   print("Match 2")

if re.match(pattern, "stingray"):
   print("Match 3")
# Out:
# Match 1
# Match 2

# %% [markdown]
# #### Grouping ()
# a group can be given as an argument to metacharacters

# %%
# The * (zero or more) occurances
pattern = r"egg(spam)*"

if re.match(pattern, "egg"):
   print("Match 1")

if re.match(pattern, "eggspamspamspamegg"):
   print("Match 2")

if re.match(pattern, "spam"):
   print("Match 3")
# Out:
# Match 1
# Match 2

# %%
# Special Sequences 
# \d, \s, \w, \D These match digits, whitespace,  word characters,anything that isn't a digit respectively.

# %%
# + one or more occurances 
pattern = r"(\D+\d)"

match = re.match(pattern, "Hi 999!")

if match:
   print("Match 1")

match = re.match(pattern, "1, 23, 456!")
if match:
   print("Match 2")

match = re.match(pattern, " ! $?")
if match:
    print("Match 3")
# Out:
# Match 1

# %%
pattern = r"([\w\.-]+)@([\w\.-]+)(\.[\w\.]+)"
text = "Please contact intro@python.com for assistance"

match = re.search(pattern, text)
if match:
   print(match.group())
# Out:
# intro@python.com

# %% [markdown]
# Regex Cheat Sheet https://www.rexegg.com/regex-quickstart.html
#
# More Regex https://docs.python.org/3.7/library/re.html

# %% [markdown]
# ## Files

# %% [markdown]
# Before files to be manipulated they need to be opened

# %%
ls
# Out:
# sample_data/

# %%
myfile = open("filename.txt", "w")

# %% [markdown]
#  w means that we open file in a writing mode, if you have content in your file, oppening with w mode will rewrite it

# %% [markdown]
# This created a filename.txt file in our working directory, the file is empty, yet.

# %%
ls
# Out:
# filename.txt  sample_data/

# %%
# let's write something to file
myfile.write("Hello World\n") # it will return the number of characters (= bytes) writen in file
# Out:
# 12

# %%
myfile.close() # after the operation you should close the file

# %%
# let's read the content 
myfile = open("filename.txt", "r") # open in reading mode
myfile.read()
# Out:
# 'Hello World\n'

# %%
myfile = open("filename.txt", "a") # open in append mode, it won't overwrite content
myfile.write("Hello Students\n")
myfile.close()

# %%
myfile = open("filename.txt", "r") # open in reading mode

# %%
myfile.readline(1) # read file line
# Out:
# 'H'

# %%
myfile.readline(  ) # read file line by line
# Out:
# 'Hello Students\n'

# %%
myfile.close()

# %%
myfile = open("filename.txt", "r") # open in reading mode

# %%
myfile.readlines() # will return each line in a list
# Out:
# ['Hello World\n', 'Hello Students\n', 'Hello Students\n']

# %%
myfile.close()

# %%
# oor
myfile = open("filename.txt")
for line in myfile:
  print(line, end="\n")
# Out:
# Hello World
#
# Hello Students
#
# Hello Students

# %% [markdown]
# __Never forget to close the file__

# %%
myfile.close()

# %% [markdown]
# For lazy people like us, developers added a **with** statement, to not close the file after every operation

# %%
with open("filename.txt", "r") as file:
  for line in file.readlines():
    print(line)
# Out:
# Hello World
#
# Hello Students
#
# Hello Students

# %%
# add some more lines to file 
with open("filename.txt", "a") as file:
  file.write("This is the 3th line")

# %%
with open("filename.txt", "r") as file:
  for line in file.readlines():
    print(line)
# Out:
# Hello World
#
# Hello Students
#
# Hello Students
#
# This is the 3th line

# %%
# something combined 
import os

# %%
for i in range(100):
  with open(f"file_#_{i}.txt", "w") as f:
    f.write("This file contains text and some numbers\n")
    for j in range(100):
        f.write(str(j))

# %%
ls
# Out:
# file_#_0.txt   file_#_29.txt  file_#_48.txt  file_#_67.txt  file_#_86.txt
# file_#_10.txt  file_#_2.txt   file_#_49.txt  file_#_68.txt  file_#_87.txt
# file_#_11.txt  file_#_30.txt  file_#_4.txt   file_#_69.txt  file_#_88.txt
# file_#_12.txt  file_#_31.txt  file_#_50.txt  file_#_6.txt   file_#_89.txt
# file_#_13.txt  file_#_32.txt  file_#_51.txt  file_#_70.txt  file_#_8.txt
# file_#_14.txt  file_#_33.txt  file_#_52.txt  file_#_71.txt  file_#_90.txt
# file_#_15.txt  file_#_34.txt  file_#_53.txt  file_#_72.txt  file_#_91.txt
# file_#_16.txt  file_#_35.txt  file_#_54.txt  file_#_73.txt  file_#_92.txt
# file_#_17.txt  file_#_36.txt  file_#_55.txt  file_#_74.txt  file_#_93.txt
# file_#_18.txt  file_#_37.txt  file_#_56.txt  file_#_75.txt  file_#_94.txt
# file_#_19.txt  file_#_38.txt  file_#_57.txt  file_#_76.txt  file_#_95.txt
# file_#_1.txt   file_#_39.txt  file_#_58.txt  file_#_77.txt  file_#_96.txt
# file_#_20.txt  file_#_3.txt   file_#_59.txt  file_#_78.txt  file_#_97.txt
# file_#_21.txt  file_#_40.txt  file_#_5.txt   file_#_79.txt  file_#_98.txt
# file_#_22.txt  file_#_41.txt  file_#_60.txt  file_#_7.txt   file_#_99.txt
# file_#_23.txt  file_#_42.txt  file_#_61.txt  file_#_80.txt  file_#_9.txt
# file_#_24.txt  file_#_43.txt  file_#_62.txt  file_#_81.txt  filename.txt
# file_#_25.txt  file_#_44.txt  file_#_63.txt  file_#_82.txt  sample_data/
# file_#_26.txt  file_#_45.txt  file_#_64.txt  file_#_83.txt
# file_#_27.txt  file_#_46.txt  file_#_65.txt  file_#_84.txt
# file_#_28.txt  file_#_47.txt  file_#_66.txt  file_#_85.txt

# %%
# let's read one of this
with open("file_#_0.txt", "r") as f:
  lines_0 = f.readlines()
  print(lines_0)
# Out:
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899']

# %%
# let's make from it something like this 
# ['This file contains text and some numbers\n', '0']

# %%
lines_0[1] = lines_0[1][:1]

# %%
lines_0
# Out:
# ['This file contains text and some numbers\n', '0']

# %%
with open("file_#_0.txt", "w") as f:
  for line in lines_0:
    f.write(line)

# %%
with open("file_#_0.txt", "r") as f:

  print(f.readlines())
# Out:
# ['This file contains text and some numbers\n', '0']

# %%
ls -t
# Out:
# filename.txt  sample_data/

# %%
import os
#for i in range(100):  os.remove(f"file_#_{i}.txt")
os.remove("filename.txt")

# %%
ls
# Out:
# sample_data/

# %%
for i in range(100):
  with open(f"file_#_{i}.txt", "w") as f:
    f.write("This file contains text and some numbers\n")
    for j in range(100):
        f.write(str(j))

# %%
ls
# Out:
# file_#_0.txt   file_#_29.txt  file_#_48.txt  file_#_67.txt  file_#_86.txt
# file_#_10.txt  file_#_2.txt   file_#_49.txt  file_#_68.txt  file_#_87.txt
# file_#_11.txt  file_#_30.txt  file_#_4.txt   file_#_69.txt  file_#_88.txt
# file_#_12.txt  file_#_31.txt  file_#_50.txt  file_#_6.txt   file_#_89.txt
# file_#_13.txt  file_#_32.txt  file_#_51.txt  file_#_70.txt  file_#_8.txt
# file_#_14.txt  file_#_33.txt  file_#_52.txt  file_#_71.txt  file_#_90.txt
# file_#_15.txt  file_#_34.txt  file_#_53.txt  file_#_72.txt  file_#_91.txt
# file_#_16.txt  file_#_35.txt  file_#_54.txt  file_#_73.txt  file_#_92.txt
# file_#_17.txt  file_#_36.txt  file_#_55.txt  file_#_74.txt  file_#_93.txt
# file_#_18.txt  file_#_37.txt  file_#_56.txt  file_#_75.txt  file_#_94.txt
# file_#_19.txt  file_#_38.txt  file_#_57.txt  file_#_76.txt  file_#_95.txt
# file_#_1.txt   file_#_39.txt  file_#_58.txt  file_#_77.txt  file_#_96.txt
# file_#_20.txt  file_#_3.txt   file_#_59.txt  file_#_78.txt  file_#_97.txt
# file_#_21.txt  file_#_40.txt  file_#_5.txt   file_#_79.txt  file_#_98.txt
# file_#_22.txt  file_#_41.txt  file_#_60.txt  file_#_7.txt   file_#_99.txt
# file_#_23.txt  file_#_42.txt  file_#_61.txt  file_#_80.txt  file_#_9.txt
# file_#_24.txt  file_#_43.txt  file_#_62.txt  file_#_81.txt  sample_data/
# file_#_25.txt  file_#_44.txt  file_#_63.txt  file_#_82.txt
# file_#_26.txt  file_#_45.txt  file_#_64.txt  file_#_83.txt
# file_#_27.txt  file_#_46.txt  file_#_65.txt  file_#_84.txt
# file_#_28.txt  file_#_47.txt  file_#_66.txt  file_#_85.txt

# %%
import glob

text_files = glob.glob("file_#_*txt" ) # list all file_#_{i}.txt files
#text_files

# %%
for file_number in range(len(text_files)):
  with open(text_files[file_number], "r") as f: 
    lines = f.readlines()
   
    lines[1] = lines[1][:file_number]

  with open(text_files[file_number], "w") as g:
    for line in lines:
      g.write(line)
    
  with open(text_files[file_number], "r") as k: # w+ read and write mode
    print( k.readlines())
# Out:
# ['This file contains text and some numbers\n']
# ['This file contains text and some numbers\n', '0']
# ['This file contains text and some numbers\n', '01']
# ['This file contains text and some numbers\n', '012']
# ['This file contains text and some numbers\n', '0123']
# ['This file contains text and some numbers\n', '01234']
# ['This file contains text and some numbers\n', '012345']
# ['This file contains text and some numbers\n', '0123456']
# ['This file contains text and some numbers\n', '01234567']
# ['This file contains text and some numbers\n', '012345678']
# ['This file contains text and some numbers\n', '0123456789']
# ['This file contains text and some numbers\n', '01234567891']
# ['This file contains text and some numbers\n', '012345678910']
# ['This file contains text and some numbers\n', '0123456789101']
# ['This file contains text and some numbers\n', '01234567891011']
# ['This file contains text and some numbers\n', '012345678910111']
# ['This file contains text and some numbers\n', '0123456789101112']
# ['This file contains text and some numbers\n', '01234567891011121']
# ['This file contains text and some numbers\n', '012345678910111213']
# ['This file contains text and some numbers\n', '0123456789101112131']
# ['This file contains text and some numbers\n', '01234567891011121314']
# ['This file contains text and some numbers\n', '012345678910111213141']
# ['This file contains text and some numbers\n', '0123456789101112131415']
# ['This file contains text and some numbers\n', '01234567891011121314151']
# ['This file contains text and some numbers\n', '012345678910111213141516']
# ['This file contains text and some numbers\n', '0123456789101112131415161']
# ['This file contains text and some numbers\n', '01234567891011121314151617']
# ['This file contains text and some numbers\n', '012345678910111213141516171']
# ['This file contains text and some numbers\n', '0123456789101112131415161718']
# ['This file contains text and some numbers\n', '01234567891011121314151617181']
# ['This file contains text and some numbers\n', '012345678910111213141516171819']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344454']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445464']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344454647']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546474']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445464748']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344454647484']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445464748495']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344454647484950']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849505']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445464748495051']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344454647484950515']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849505152']
# ['This file contains text and some numbers\n', '0123456789101112131415161718192021222324252627282930313233343536373839404142434445464748495051525']
# ['This file contains text and some numbers\n', '01234567891011121314151617181920212223242526272829303132333435363738394041424344454647484950515253']
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849505152535']

# %%
with open("file_#_28.txt", "r") as f:
  print(f.readlines())
# Out:
# ['This file contains text and some numbers\n', '012345678910111213141516171819202122232425262728293031323334353637383940414243444546']

# %%
import os
os.path.isfile("file_#_28.txt")
# Out:
# False

# %%
# print different experience 
import sys
import time
with open("somefile.txt", "w") as file:
  file.write("This is sample text written in sample file")
  
with open("somefile.txt", "r") as file:
  outtext = file.readlines()


for i in outtext[0]:
    sys.stdout.write(i)
    sys.stdout.flush()
    time.sleep(0.3)
# Out:
# This is sample text written in sample file

# %% [markdown]
# # Exceptions

# %% [markdown]
# Short: If you faced or will face in some probably errors in your code, it's smart move to use excpetion handling.
# Let's discuss it with examples.

# %%
# the function just returns the item in given index
def fetcher(obj, index):
  return obj[index]

# %%
# works really well 
fetcher("spam", 2)
# Out:
# 'a'

# %%
# but 
fetcher("spam", 15)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-a0f75e3cab80> in <module>()
# ----> 1 fetcher("spam", 15)
#
# <ipython-input-73-c6d70cc53a2e> in fetcher(obj, index)
#       1 def fetcher(obj, index):
# ----> 2   return obj[index]
#
# IndexError: string index out of range

# %% [markdown]
# For such things like catching errors, and helping your code to move forward and to not print errors we use Exceptions. Server programs, for instance, typically
# need to remain active even after internal errors.

# %% [markdown]
# ### Exception Syntax
#
# ```
# try:
#   statement
# except:
#   print("Error message")
# else: # optional
#   statement
# finally: # optional
#   statement
#
# ```

# %%
try:
  print(fetcher("Spa", 15))
except IndexError:
  print('got exception')
# Out:
# got exception

# %%
try:
  fetcher("Spa", 1)
except IndexError:
  print('got exception')
print("Continuing the code")
# Out:
# Continuing the code

# %%
try:
  fetcher("Spa", 4)
except:
  print('got exception')
# Out:
# got exception

# %%
try:
  fetcher("Spa", 4)
except ZeroDivisionError:
  print('got exception')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-10343ff9d9fb> in <module>()
#       1 try:
# ----> 2   fetcher("Spa", 4)
#       3 except ZeroDivisionError:
#       4   print('got exception')
#
# <ipython-input-73-c6d70cc53a2e> in fetcher(obj, index)
#       1 def fetcher(obj, index):
# ----> 2   return obj[index]
#
# IndexError: string index out of range

# %% [markdown]
# ### Some error types
# ```
# ImportError: an import fails;
# IndexError: a list is indexed with an out-of-range number;
# NameError: an unknown variable is used;
# SyntaxError: the code can't be parsed properly;
# TypeError: a function is called on a value of an inappropriate type;
# ValueError: a function is called on a value of the correct type, but with an inappropriate value.
#
# ```
# There also other build-in Exceptions, and exceptions in third party libraries.

# %%
try:
   variable = 10
   print(variable + "hello")
   print(variable /0)
except ZeroDivisionError:
   print("Divided by zero")
except (ValueError, TypeError):
   print("Error occurred")
# Out:
# Error occurred

# %% [markdown]
# ### Finally Clause

# %%
# finnaly executed no matter what, and is generally used to release external resources.
try:
  fetcher("Spa", 4)
except IndexError:
  print('got exception')
finally:
  print("Continuing the code")
# Out:
# got exception
# Continuing the code

# %%
try:
  fetcher("Spa", 4)
finally:
  print("Continuing the code")
print("Some text")
# Out:
# Continuing the code
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-700d34f048c7> in <module>()
#       1 try:
# ----> 2   fetcher("Spa", 4)
#       3 finally:
#       4   print("Continuing the code")
#       5 print("Some text")
#
# <ipython-input-14-c6d70cc53a2e> in fetcher(obj, index)
#       1 def fetcher(obj, index):
# ----> 2   return obj[index]
#
# IndexError: string index out of range

# %%
try:
  fetcher("Spa", 2)
finally:
  print("Continuing the code")
# Out:
# Continuing the code

# %%
try:
  fetcher("Spa", 4)
except Exception as e:
  print(e)
finally:
  print("Continuing the code")
print("Some text")
# Out:
# string index out of range
# Continuing the code
# Some text

# %%
# if you want your code to stop after exception
import sys

try:
    f = open('test_file.txt') #the file name is correct now
    var = wrong_var #we have a wrong variable assignment
except Exception:
    print('Some kind of exception occured')
    sys.exit(1)
print('some code')
# Out:
# Some kind of exception occured
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### Raise

# %%
# We can raise exceptions by ourself
print(1)
raise ValueError
print(2)
# Out:
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-990863ff3a0f> in <module>()
#       1 print(1)
# ----> 2 raise ValueError
#       3 print(2)
#
# ValueError:
# ERROR! Session/line number was not unique in database. History logging moved to new session 60

# %%
try:
  raise IndexError
except IndexError:
  print('propagating')
  raise
# Out:
# propagating
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-c36d72d22282> in <module>()
#       1 try:
# ----> 2   raise IndexError
#       3 except IndexError:
#       4   print('propagating')
#       5   raise
#
# IndexError:

# %% [markdown]
# ### Else Clause

# %%
try:
    f = open('testfile.txt') 
except FileNotFoundError as e:
    print(e)
else:
    print('Executing the else clause.')
# Out:
# [Errno 2] No such file or directory: 'testfile.txt'

# %%
try:
    f = open('testfile.txt') 
except FileNotFoundError as e:
    print(e)
else:
    print('Executing the else clause.')
print("This part is executed anyways.")
# Out:
# [Errno 2] No such file or directory: 'testfile.txt'
# This part is executed anyways.

# %%
try:
    f = open('test_file.txt', "w") 
except FileNotFoundError as e:
    print(e)
else:
    try:
        f = open('newfile.txt') 
    except FileNotFoundError as e:
        print(e)
finally:
  f.close()
try:
  f = open('test_file.txt', "w") 
  f.write("text")
except Exception as e:
  print(e)
finally:
  f.close()
# Out:
# [Errno 2] No such file or directory: 'newfile.txt'

# %% [markdown]
# As you saw here, ``finally`` can be used to clean after our code, closing file, closing the server, etc.

# %% [markdown]
# # Assertions

# %% [markdown]
#  Check if a fact is True and assert if its False. Used mainly for checking types, values of argument and the output of functions, also, as a debugging tool.

# %% [markdown]
#  If the condition is not satisfied, the program is stopped and gives an AssertionError.
#
#  ``assert <condition> ``

# %% [markdown]
# If the condition is not satisfied, the program is stopped and gives an AssertionError + prints the specified error message.
#
# `` assert <condition>,<error message>``

# %%
def avg(marks):
    assert len(marks) != 0
    return sum(marks)/len(marks)

mark1 = []
print("Average of mark1:",avg(mark1))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-90-0876cd836acd> in <module>()
#       4
#       5 mark1 = []
# ----> 6 print("Average of mark1:",avg(mark1))
#
# <ipython-input-90-0876cd836acd> in avg(marks)
#       1 def avg(marks):
# ----> 2     assert len(marks) != 0
#       3     return sum(marks)/len(marks)
#       4
#       5 mark1 = []
#
# AssertionError:

# %%
mark1 = [1,2,4]
print("Average of mark1:",avg(mark1))
# Out:
# Average of mark1: 2.3333333333333335

# %%
def avg(marks):
    assert len(marks) != 0,"List is empty."
    return sum(marks)/len(marks)

mark2 = [55,88,78,90,79]
print("Average of mark2:",avg(mark2))

mark1 = []
print("Average of mark1:",avg(mark1))
# Out:
# Average of mark2: 78.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-92-4a885bedd40a> in <module>()
#       7
#       8 mark1 = []
# ----> 9 print("Average of mark1:",avg(mark1))
#
# <ipython-input-92-4a885bedd40a> in avg(marks)
#       1 def avg(marks):
# ----> 2     assert len(marks) != 0,"List is empty."
#       3     return sum(marks)/len(marks)
#       4
#       5 mark2 = [55,88,78,90,79]
#
# AssertionError: List is empty.
