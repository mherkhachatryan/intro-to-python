# %% [markdown]
# # Pandas Overwiew

# %% [markdown]
#  It
# contains data structures and data manipulation tools designed to make data cleaning
# and analysis fast and easy in Python. pandas is often used in tandem with numerical
# computing tools like NumPy and SciPy, analytical libraries like statsmodels and
# scikit-learn, and data visualization libraries like matplotlib. pandas adopts significant
# parts of NumPy’s idiomatic style of array-based computing, especially array-based
# functions and a preference for data processing without for loops.
# While pandas adopts many coding idioms from NumPy, the biggest difference is that
# pandas is designed for working with tabular or heterogeneous data. NumPy, by con‐
# trast, is best suited for working with homogeneous numerical array data.
# Since becoming an open source project in 2010, pandas has matured into a quite
# large library that’s applicable in a broad set of real-world use cases. The developer
# community has grown to over 800 distinct contributors, who’ve been helping build
# the project as they’ve used it to solve their day-to-day data problems.
#
# <img src = "https://i.redd.it/c6h7rok9c2v31.jpg" width = 600/>

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas Data  Structures
# Pandas deals with the following three data structures:
#
#     Series
#     DataFrame
#     Panel (ignore this one for now)

# %% [markdown]
# ### Series
# A Series is a one-dimensional array-like object containing a sequence of values (of
# similar types to NumPy types) and an associated array of data labels, called its index.
#
#
# ``pandas.Series(data, index, dtype, copy)``

# %% [markdown]
# #### Creating Series

# %%
# empty  series
s = pd.Series()
print(s)
# Out:
# Series([], dtype: float64)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
np.random.seed(42)
np_array = np.random.randint(low=-15, high=20, size=4)
np_array
# Out:
# array([13, -1, -8,  5])

# %%
# series from an array
pd_series_1 = pd.Series(np_array)
pd_series_1
# Out:
# 0    13
# 1    -1
# 2    -8
# 3     5
# dtype: int64

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
print(obj.index) # like range
print(obj.index.tolist())
# Out:
# RangeIndex(start=0, stop=4, step=1)
# [0, 1, 2, 3]

# %%
# we can change indices
pd_series_3 = pd.Series(np_array, index=['1st day', '2nd day', '3rd day', '4th day'])
pd_series_3
# Out:
# 1st day    13
# 2nd day    -1
# 3rd day    -8
# 4th day     5
# dtype: int64

# %%
# and give a series a name
pd_series_3 = pd.Series(np_array, index=['1st day', '2nd day', '3rd day', '4th day'], name='Temperature')
pd_series_3
# Out:
# 1st day    13
# 2nd day    -1
# 3rd day    -8
# 4th day     5
# Name: Temperature, dtype: int64

# %%
# a series from a scalar
s = pd.Series(5, index=[0, 1, 2, 3, 4, 5, 23])
print(s)
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 23    5
# dtype: int64

# %%
# series from a dictionary
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)

print(data)
print('\n')
print(s)
# Out:
# {'a': 0.0, 'b': 1.0, 'c': 2.0}
#
#
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %% [markdown]
# #### Series Manipulation

# %%
# we can select values by indices
# slice it like lists 
print(pd_series_3[0])
print('*'*5)
print(pd_series_3[1:3])
print('*'*5)
print(pd_series_3[::-1])
# Out:
# 13
# *****
# 2nd day   -1
# 3rd day   -8
# Name: Temperature, dtype: int64
# *****
# 4th day     5
# 3rd day    -8
# 2nd day    -1
# 1st day    13
# Name: Temperature, dtype: int64

# %%
# get by assigned indices too 
pd_series_3['2nd day']
# Out:
# -1

# %%
# select multiple indices
pd_series_3[['2nd day', "4th day"]]
# Out:
# 2nd day   -1
# 4th day    5
# Name: Temperature, dtype: int64

# %%
obj2 * 2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
np.exp(pd_series_3)
# Out:
# 1st day    442413.392009
# 2nd day         0.367879
# 3rd day         0.000335
# 4th day       148.413159
# Name: Temperature, dtype: float64

# %%
pd_series_3 + 100
print(pd_series_3)
# Out:
# 1st day    13
# 2nd day    -1
# 3rd day    -8
# 4th day     5
# Name: Temperature, dtype: int64

# %%
# we can play with series as with dictionaries
'1st day' in pd_series_3
# Out:
# True

# %%
pd_series_3.sort_index()
# Out:
# 1st day    13
# 2nd day    -1
# 3rd day    -8
# 4th day     5
# Name: Temperature, dtype: int64

# %%
pd_series_3.sort_values()
# Out:
# 3rd day    -8
# 2nd day    -1
# 4th day     5
# 1st day    13
# Name: Temperature, dtype: int64

# %%
term_1 = pd.Series(np.random.randint(0, 10, 5))
term_1.shape
# Out:
# (5,)

# %%
# working with dates are too easy now
date_range = pd.date_range('20190201', periods=10)
pd_series_4 = pd.Series(np.random.rand(10), date_range)
pd_series_4
# Out:
# 2019-02-01    0.230894
# 2019-02-02    0.241025
# 2019-02-03    0.683264
# 2019-02-04    0.609997
# 2019-02-05    0.833195
# 2019-02-06    0.173365
# 2019-02-07    0.391061
# 2019-02-08    0.182236
# 2019-02-09    0.755361
# 2019-02-10    0.425156
# Freq: D, dtype: float64

# %%
pd_series_4 > 0.5
# Out:
# 2019-01-01     True
# 2019-01-02    False
# 2019-01-03     True
# 2019-01-04     True
# 2019-01-05    False
# 2019-01-06    False
# 2019-01-07     True
# 2019-01-08     True
# 2019-01-09    False
# 2019-01-10    False
# Freq: D, dtype: bool

# %%
pd_series_4[pd_series_4>np.mean(pd_series_4)]
# Out:
# 2019-01-01    0.456070
# 2019-01-02    0.785176
# 2019-01-04    0.514234
# 2019-01-05    0.592415
# 2019-01-07    0.607545
# 2019-01-10    0.948886
# dtype: float64

# %%
pd_series_4[(pd_series_4 > 0.5) & (pd_series_4 < 0.6)]
# Out:
# 2019-01-08    0.563288
# Freq: D, dtype: float64

# %%
pd_series_4[(pd_series_4 > 0.6) | (pd_series_4 < 0.2)]
# Out:
# 2019-01-01    0.983231
# 2019-01-03    0.859940
# 2019-01-04    0.680308
# 2019-01-06    0.013265
# 2019-01-07    0.942202
# 2019-01-10    0.015966
# dtype: float64

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
print(obj3, "\n")
print(obj4)
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64
#
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
# NaN (not a number)
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj3.index.name = "state"
obj3.name = "Population"

obj3
# Out:
# state
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# Name: Population, dtype: int64

# %% [markdown]
# ### Dataframe

# %% [markdown]
# A DataFrame represents a rectangular table of data and contains an ordered collec‐
# tion of columns, each of which can be a different value type (numeric, string,
# boolean, etc.). The DataFrame has both a row and column index; it can be thought of
# as a dict of Series all sharing the same index. Under the hood, the data is stored as one
# or more two-dimensional blocks rather than a list, dict, or some other collection of
# one-dimensional arrays.

# %% [markdown]
# #### Creating Dataframes

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = [1,2,3,4,5]
df = pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data = [1,2,3,4,5]

df = pd.DataFrame(data, columns = ['first'])
print(df)
df
# Out:
#    first
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#    first
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
df
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
data = {'col_1': [3, 2, 1, 0], 'col_2': ["a", 'b', 'c', 'd']}
pd.DataFrame.from_dict(data)
# Out:
#    col_1 col_2
# 0      3     a
# 1      2     b
# 2      1     c
# 3      0     d

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df1 = pd.DataFrame(data, index=['first', 'second']) 

df1
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df1 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b'],) 

df1
# Out:
#         a   b
# first   1   2
# second  5  10

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df1 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b', 'c', 'd']) 
df1
# Out:
#         a   b     c   d
# first   1   2   NaN NaN
# second  5  10  20.0 NaN

# %% [markdown]
# #### Index Selection

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four','five', 'six'])
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2['state'][0]
# Out:
# 'Ohio'

# %%
frame2.columns.tolist()
# Out:
# ['year', 'state', 'pop', 'debt']

# %%
frame2["year"]
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
type(frame2["year"])
# Out:
# pandas.core.series.Series

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
frame2[["year", "pop"]]
# Out:
#        year  pop
# one    2000  1.5
# two    2001  1.7
# three  2002  3.6
# four   2001  2.4
# five   2002  2.9
# six    2003  3.2

# %%
frame2["one":"four"]
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN

# %%
frame2[3:1:-1]
# Out:
#        year   state  pop debt
# four   2001  Nevada  2.4  NaN
# three  2002    Ohio  3.6  NaN

# %% [markdown]
# the special indexing operators
# loc and iloc . They enable you to select a subset of the rows and columns from a
# DataFrame with NumPy-like notation using either axis labels ( loc ) or integers
# ( iloc ).

# %%
data = [['Alex',10, 2009],['Bob',12, 2011],['Clarke',13, 2012]]
df = pd.DataFrame(data,columns=['Name','Age', 'Year'])
df
# Out:
#      Name  Age  Year
# 0    Alex   10  2009
# 1     Bob   12  2011
# 2  Clarke   13  2012

# %%
df.loc[df.index[[0, 2]], ['Age', 'Year']]
# Out:
#    Age  Year
# 0   10  2009
# 2   13  2012

# %%
df.loc[df.index[:2], ['Age', 'Year']]
# Out:
#    Age  Year
# 0   10  2009
# 1   12  2011

# %%
df.loc[2, ["Age", "Name"]]
# Out:
# Age         13
# Name    Clarke
# Name: 2, dtype: object

# %%
df.iloc[2,[1,0]]
# Out:
# Age         13
# Name    Clarke
# Name: 2, dtype: object

# %% [markdown]
# Adding Condition to Dataframe

# %%
df['Age']==10
# Out:
# 0     True
# 1    False
# 2    False
# Name: Age, dtype: bool

# %%
df[df['Age']==10]
# Out:
#    Name  Age  Year
# 0  Alex   10  2009

# %%
df['Age']==10
# Out:
# 0     True
# 1    False
# 2    False
# Name: Age, dtype: bool

# %%
df[(df['Age']>10) & (df['Year']>2000)]
# Out:
#      Name  Age  Year
# 1     Bob   12  2011
# 2  Clarke   13  2012

# %% [markdown]
# Adding New Column

# %%
data = [['Alex',10, 2009],['Bob',12, 2011],['Clarke',13, 2012]]
df = pd.DataFrame(data,columns=['Name','Age', 'Year'])


df
# Out:
#      Name  Age  Year
# 0    Alex   10  2009
# 1     Bob   12  2011
# 2  Clarke   13  2012

# %%
df['Gender']=pd.Series(['male','male','male'])
df['Gender'] = 'male'
df
# Out:
#      Name  Age  Year Gender
# 0    Alex   10  2009   male
# 1     Bob   12  2011   male
# 2  Clarke   13  2012   male

# %%
df['Gender']=['male','male','male']
df['Gender'] = 'male'
df
# Out:
#      Name  Age  Year Gender
# 0    Alex   10  2009   male
# 1     Bob   12  2011   male
# 2  Clarke   13  2012   male

# %%
df['Gender'] = 1
df
# Out:
#      Name  Age  Year  Gender
# 0    Alex   10  2009       1
# 1     Bob   12  2011       1
# 2  Clarke   13  2012       1

# %%
del df["Age"]
df
# Out:
#      Name  Year  Gender
# 0    Alex  2009       1
# 1     Bob  2011       1
# 2  Clarke  2012       1

# %%
data = [['Alex',10],['Bob',12],['Clarke',13],['Jane',16],['Anna',10]]
df = pd.DataFrame(data,columns=['Name','Age'])

print(df)
print('\n')

df2 = pd.DataFrame([['Alice',10],['Tom',12]], columns = ['Name','Age'])

print(df2)
print('\n')

df = df.append(df2)
print(df)
print('\n')
###note!  df.loc[0]
#print(df.loc[0])

df = df.drop(1)
print('after drop\n',df)

df.index=np.arange(len(df))
df
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13
# 3    Jane   16
# 4    Anna   10
#
#
#     Name  Age
# 0  Alice   10
# 1    Tom   12
#
#
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13
# 3    Jane   16
# 4    Anna   10
# 0   Alice   10
# 1     Tom   12
#
#
# after drop
#       Name  Age
# 0    Alex   10
# 2  Clarke   13
# 3    Jane   16
# 4    Anna   10
# 0   Alice   10
#      Name  Age
# 0    Alex   10
# 1  Clarke   13
# 2    Jane   16
# 3    Anna   10
# 4   Alice   10

# %%
df
# Out:
#      Name  Year  Gender
# 0    Alex  2009       1
# 1     Bob  2011       1
# 2  Clarke  2012       1

# %% [markdown]
# #### Some Usefull Methods and  Functions

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9},
       'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}
frame3 = pd.DataFrame(pop)

# %%
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
frame3.T
# Out:
#         2001  2002  2000
# Nevada   2.4   2.9   NaN
# Ohio     1.7   3.6   1.5

# %%
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
frame3.index.name = 'year'; frame3.columns.name = 'state'

# %%
frame3
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
frame3.values
# Out:
# array([[2.4, 1.7],
#        [2.9, 3.6],
#        [nan, 1.5]])

# %%
frame3.reindex([2010,2011,2012])
frame3
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
frame3['Nevada'].value_counts()
# Out:
# 2.9    1
# 2.4    1
# Name: Nevada, dtype: int64

# %%
df.head(2)
# Out:
#    Name  Year  Gender
# 0  Alex  2009       1
# 1   Bob  2011       1

# %%
df.tail(2)
# Out:
#     Name  Age
# 3   Anna   10
# 4  Alice   10

# %%
df.sample(3)
# Out:
#      Name  Year  Gender
# 0    Alex  2009       1
# 2  Clarke  2012       1
# 1     Bob  2011       1

# %%
df.shape
# Out:
# (3, 3)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df1 = pd.DataFrame(np.random.randn(5,3),columns=['col1','col2','col3'])
df_reindexed = df1.reindex(index=[0,2,5,10,8])

print(df1)
print('\n')
print(df_reindexed)
# Out:
#        col1      col2      col3
# 0 -0.461466  0.066657 -0.176286
# 1  1.200893  0.698399 -0.171629
# 2 -0.907187  1.188626  0.785532
# 3  2.656010  0.263486  1.641771
# 4  0.460816  0.085923 -1.509957
#
#
#         col1      col2      col3
# 0  -0.461466  0.066657 -0.176286
# 2  -0.907187  1.188626  0.785532
# 5        NaN       NaN       NaN
# 10       NaN       NaN       NaN
# 8        NaN       NaN       NaN

# %% [markdown]
# NumPy ufuncs (element-wise array methods) also work with pandas objects:

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah    0.721502 -0.843420 -0.513325
# Ohio   -0.043537 -0.275301 -1.563067
# Texas  -0.795631  0.930584  0.677767
# Oregon  0.698440  0.173602  0.662285

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    0.721502  0.843420  0.513325
# Ohio    0.043537  0.275301  1.563067
# Texas   0.795631  0.930584  0.677767
# Oregon  0.698440  0.173602  0.662285

# %%
f = lambda x: x.max() - x.min()
frame.apply(f)
# Out:
# b    2.096149
# d    2.351763
# e    1.635660
# dtype: float64

# %%
frame
# Out:
#                b         d         e
# Utah    0.721502 -0.843420 -0.513325
# Ohio   -0.043537 -0.275301 -1.563067
# Texas  -0.795631  0.930584  0.677767
# Oregon  0.698440  0.173602  0.662285

# %%
frame.apply(f, axis='columns')
# Out:
# Utah      0.350716
# Ohio      1.534318
# Texas     2.208433
# Oregon    1.332379
# dtype: float64

# %%
def f(x):
  return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
frame.apply(f)
# Out:
#             b         d         e
# min -0.691030 -2.213294 -1.193909
# max  1.405119  0.138470  0.441751

# %%
# sorting
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=['three', 'one'],
                     columns=['d', 'a', 'b', 'c'])

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis=1)
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1, ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
obj.sort_values()
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# Axis Indexes with Duplicate Labels

# %%
obj = pd.Series(range(5), index=['a', 'a', 'b', 'b', 'c'])

# %%
obj.index.is_unique
# Out:
# False

# %%
obj['a']
# Out:
# a    0
# a    1
# dtype: int64

# %% [markdown]
# Working with nan missing values

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f','h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#         one       two     three
# a  0.241122 -0.168205  1.164769
# b       NaN       NaN       NaN
# c -0.245748 -0.769668  1.212172
# d       NaN       NaN       NaN
# e  1.233497 -1.574155  0.637953
# f -2.044423  1.069481 -0.933763
# g       NaN       NaN       NaN
# h  0.784208 -0.614876  0.332892

# %%
df['one'].isnull()
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
df['one'].notnull()
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: one, dtype: bool

# %%
df1 = df.fillna( 0) # fill next valid observation
df1
# Out:
#         one       two     three
# a  0.241122 -0.168205  1.164769
# b  0.000000  0.000000  0.000000
# c -0.245748 -0.769668  1.212172
# d  0.000000  0.000000  0.000000
# e  1.233497 -1.574155  0.637953
# f -2.044423  1.069481 -0.933763
# g  0.000000  0.000000  0.000000
# h  0.784208 -0.614876  0.332892

# %%
df2 = df.dropna()
df2
# Out:
#         one       two     three
# a  0.241122 -0.168205  1.164769
# c -0.245748 -0.769668  1.212172
# e  1.233497 -1.574155  0.637953
# f -2.044423  1.069481 -0.933763
# h  0.784208 -0.614876  0.332892

# %% [markdown]
# Other cool stuff

# %%
df = pd.DataFrame({'one':[10,20,30,40,50,2000],'two':[1000,0,30,40,50,60]})

print(df)
print('\n')
df1 = df.replace({1000:10,2000:60})
df1
# Out:
#     one   two
# 0    10  1000
# 1    20     0
# 2    30    30
# 3    40    40
# 4    50    50
# 5  2000    60
#    one  two
# 0   10   10
# 1   20    0
# 2   30   30
# 3   40   40
# 4   50   50
# 5   60   60

# %% [markdown]
# #### Groupby

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
                     'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

print(df)
print('\n')
print (df.groupby('Team'))
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690
#
#
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f553a8a4400>

# %%
x = df.groupby('Team')
print (x.mean())
# Out:
#             Rank         Year      Points
# Team
# Devils  2.500000  2014.500000  768.000000
# Kings   1.666667  2015.666667  761.666667
# Riders  1.750000  2015.500000  762.250000
# Royals  2.500000  2014.500000  752.500000
# kings   4.000000  2015.000000  812.000000

# %%
print (df.groupby('Team').median())
print (df.groupby('Team')[['Rank', 'Points']].median())
# Out:
#         Rank    Year  Points
# Team
# Devils   2.5  2014.5   768.0
# Kings    1.0  2016.0   756.0
# Riders   2.0  2015.5   741.5
# Royals   2.5  2014.5   752.5
# kings    4.0  2015.0   812.0
#         Rank  Points
# Team
# Devils   2.5   768.0
# Kings    1.0   756.0
# Riders   2.0   741.5
# Royals   2.5   752.5
# kings    4.0   812.0

# %% [markdown]
# View the groups

# %%
print (df.groupby('Team').groups)
# Out:
# {'Devils': Int64Index([2, 3], dtype='int64'), 'Kings': Int64Index([4, 6, 7], dtype='int64'), 'Riders': Int64Index([0, 1, 8, 11], dtype='int64'), 'Royals': Int64Index([9, 10], dtype='int64'), 'kings': Int64Index([5], dtype='int64')}

# %%
df.groupby("Year").groups
# Out:
# {2014: Int64Index([0, 2, 4, 9], dtype='int64'),
#  2015: Int64Index([1, 3, 5, 10], dtype='int64'),
#  2016: Int64Index([6, 8], dtype='int64'),
#  2017: Int64Index([7, 11], dtype='int64')}

# %%
grouped = df.groupby('Year')

for name,group in grouped:
    print (name)
    print (group)
    print('\n')
# Out:
# 2014
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
#
#
# 2015
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
#
#
# 2016
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
#
#
# 2017
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %% [markdown]
# #### Merging and Joining

# %%
df1 = pd.DataFrame({
         'id':[1,2,3,4,5],
         'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5']})
df2 = pd.DataFrame(
         {'id':[1,2,3,4,5],
         'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
         'subject_id':['sub2','sub4','sub3','sub6','sub5']})
print (df1)
print('\n')
print (df2)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
#
#
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %%
pd.merge(df1,df2,on='id')
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %%
# looks for equal touples
print(df1)
print(df2)

pd.merge(df1,df2,on=['id','subject_id'])
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5
#    id  Name_x subject_id Name_y
# 0   4   Alice       sub6  Bryce
# 1   5  Ayoung       sub5  Betty

# %% [markdown]
# #### Arithmetic and Data Alignment

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])
print(df1, df2, sep = "\n\n")
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0
#
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1+df2
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list('abcde'))
df2.loc[1, 'b'] = np.nan
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %%
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   NaN   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1 + df2
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0   NaN  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN

# %%
df1.add(df2, fill_value=0)
# Out:
#       a     b     c     d     e
# 0   0.0   2.0   4.0   6.0   4.0
# 1   9.0   5.0  13.0  15.0   9.0
# 2  18.0  20.0  22.0  24.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}
df = pd.DataFrame(d)

# %%
df
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65

# %%
df.sum(axis=0) #sum of values in each column ,type doesn't matter
# Out:
# Name      TomJamesRickyVinSteveSmithJackLeeDavidGasperBe...
# Age                                                     382
# Rating                                                44.92
# dtype: object

# %%
df.sum(axis=1) #sum of only numerical values in each row
# Out:
# 0     29.23
# 1     29.24
# 2     28.98
# 3     25.56
# 4     33.20
# 5     33.60
# 6     26.80
# 7     37.78
# 8     42.98
# 9     34.80
# 10    55.10
# 11    49.65
# dtype: float64

# %%
df[['Age']].sum(axis=0)
# Out:
# Age    382
# dtype: int64

# %%
df.mean() #of the numerical columns
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %%
df.std()
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %%
df.describe()
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %% [markdown]
# ### Working With Real Data

# %% [markdown]
# To connect kaggle API to Google Colab.
# Refere [here](https://www.kaggle.com/general/74235)

# %%
"""! pip install -q kaggle
from google.colab import files 
files.upload()
! mkdir ~/.kaggle 
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json"""
# Out:
#      <input type="file" id="files-e0b0e07f-3012-435d-922d-3489f9747dd7" name="files[]" multiple disabled />
#      <output id="result-e0b0e07f-3012-435d-922d-3489f9747dd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
 ! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                            title                                                size  lastUpdated          downloadCount
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge              COVID-19 Open Research Dataset Challenge (CORD-19)    1GB  2020-04-03 22:53:52          46326
# roche-data-science-coalition/uncover                           UNCOVER COVID-19 Challenge                          123MB  2020-04-08 22:04:30           2044
# fireballbyedimyrnmom/us-counties-covid-19-dataset              US counties COVID 19 dataset                        334KB  2020-04-09 13:48:30           2301
# ryanxjhan/cbc-news-coronavirus-articles-march-26               CBC News Coronavirus/COVID-19 Articles (NLP)          6MB  2020-03-27 23:23:07            505
# bappekim/air-pollution-in-seoul                                Air Pollution in Seoul                               20MB  2020-04-03 16:33:49            633
# danevans/world-bank-wdi-212-health-systems                     World Bank WDI 2.12 - Health Systems                  6KB  2020-03-29 19:00:14            680
# vitaliymalcev/russian-passenger-air-service-20072020           Russian passenger air service 2007-2020             239KB  2020-04-02 22:27:03            393
# eswarchandt/amazon-music-reviews                               Amazon Musicual Instruments Reviews                   5MB  2020-03-29 02:59:52            425
# dheerajmpai/hospitals-and-beds-in-india                        Hospitals and beds in India (Statewise)               5KB  2020-03-27 14:05:50            574
# lakritidis/identifying-influential-bloggers-techcrunch         Identifying Influential Bloggers: Techcrunch        112MB  2020-03-30 19:22:09            114
# monogenea/birdsongs-from-europe                                Bird songs from Europe (xeno-canto)                   7GB  2020-03-23 15:35:20             72
# trtmio/project-coviewed-subreddit-coronavirus-news-corpus      Project COVIEWED Coronavirus News Corpus              9MB  2020-04-06 09:01:01             83
# sobhanmoosavi/us-accidents                                     US Accidents (3.0 million records)                  199MB  2020-01-17 04:45:09          12867
# kimjihoo/coronavirusdataset                                    Data Science for COVID-19 (DS4C)                      3MB  2020-04-07 15:09:23          26533
# sudalairajkumar/novel-corona-virus-2019-dataset                Novel Corona Virus 2019 Dataset                     706KB  2020-04-09 06:36:40         130632
# clmentbisaillon/fake-and-real-news-dataset                     Fake and real news dataset                           41MB  2020-03-26 18:51:15            916
# unanimad/dataisbeautiful                                       Reddit - Data is Beautiful                           11MB  2020-04-01 12:10:09           1598
# jessemostipak/hotel-booking-demand                             Hotel booking demand                                  1MB  2020-02-13 01:27:20          13341
# paultimothymooney/covid19-containment-and-mitigation-measures  COVID-19 containment and mitigation measures        141KB  2020-04-08 15:26:16           1451
# rubenssjr/brasilian-houses-to-rent                             brazilian_houses_to_rent                            282KB  2020-03-25 22:51:17           1766

# %%
! kaggle datasets download -d eswarchandt/amazon-music-reviews
# Out:
# Downloading amazon-music-reviews.zip to /content
#   0% 0.00/4.69M [00:00<?, ?B/s]
# 100% 4.69M/4.69M [00:00<00:00, 42.9MB/s]

# %%
ls
# Out:
# amazon-music-reviews.zip  kaggle.json  sample_data/

# %%
! mkdir amazon

# %%
! unzip amazon-music-reviews.zip -d amazon
# Out:
# Archive:  amazon-music-reviews.zip
#   inflating: amazon/Musical_Instruments_5.json
#   inflating: amazon/Musical_instruments_reviews.csv

# %%
ls amazon/*csv
# Out:
# amazon/Musical_instruments_reviews.csv

# %%
amazon_data= pd.read_csv("amazon/Musical_instruments_reviews.csv")

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10261 entries, 0 to 10260
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      10261 non-null  object
#  1   asin            10261 non-null  object
#  2   reviewerName    10234 non-null  object
#  3   helpful         10261 non-null  object
#  4   reviewText      10254 non-null  object
#  5   overall         10261 non-null  float64
#  6   summary         10261 non-null  object
#  7   unixReviewTime  10261 non-null  int64
#  8   reviewTime      10261 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 721.6+ KB

# %%
amazon_data.sample(5)
# Out:
#            reviewerID        asin  ... unixReviewTime   reviewTime
# 2534    AZ0LJNEP2VRD1  B0002GX6V2  ...     1336003200   05 3, 2012
# 1458   A1786LAQ18LHDC  B0002E1O2C  ...     1356912000  12 31, 2012
# 6987    A8MTE6SIYM0GY  B001SC4I16  ...     1379203200  09 15, 2013
# 10207  A20OBCQWBKCGZT  B00HFRXACG  ...     1404691200   07 7, 2014
# 3443   A3HCK3UXD6WS4G  B0002OS9FC  ...     1396396800   04 2, 2014
#
# [5 rows x 9 columns]

# %%
amazon_data.shape
# Out:
# (10261, 9)

# %%
amazon_data.describe()
# Out:
#             overall  unixReviewTime
# count  10261.000000    1.026100e+04
# mean       4.488744    1.360606e+09
# std        0.894642    3.779735e+07
# min        1.000000    1.095466e+09
# 25%        4.000000    1.343434e+09
# 50%        5.000000    1.368490e+09
# 75%        5.000000    1.388966e+09
# max        5.000000    1.405987e+09

# %%
amazon_data.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime'],
#       dtype='object')

# %%
amazon_data.iloc[0]
# Out:
# reviewerID                                           A2IBPI20UZIR0U
# asin                                                     1384719342
# reviewerName       cassandra tu "Yeah, well, that's just like, u...
# helpful                                                      [0, 0]
# reviewText        Not much to write about here, but it does exac...
# overall                                                           5
# summary                                                        good
# unixReviewTime                                           1393545600
# reviewTime                                              02 28, 2014
# Name: 0, dtype: object

# %%
amazon_data.iloc[1:3, 1:3]
# Out:
#          asin                   reviewerName
# 1  1384719342                           Jake
# 2  1384719342  Rick Bennette "Rick Bennette"

# %%
len(amazon_data.overall.unique())
# Out:
# 5

# %%
amazon_data[amazon_data.overall == 5]
# Out:
#            reviewerID        asin  ... unixReviewTime   reviewTime
# 0      A2IBPI20UZIR0U  1384719342  ...     1393545600  02 28, 2014
# 1      A14VAT5EAX3D9S  1384719342  ...     1363392000  03 16, 2013
# 2      A195EZSQDW3E21  1384719342  ...     1377648000  08 28, 2013
# 3      A2C00NNG1ZQQG2  1384719342  ...     1392336000  02 14, 2014
# 4       A94QU4C90B1AX  1384719342  ...     1392940800  02 21, 2014
# ...               ...         ...  ...            ...          ...
# 10251  A3M1PLEYNDEYO8  B00JBIVXGC  ...     1404172800   07 1, 2014
# 10252  A1SD1C8XK3Z3V1  B00JBIVXGC  ...     1404086400  06 30, 2014
# 10254  A306NASGVUDFKF  B00JBIVXGC  ...     1404432000   07 4, 2014
# 10256  A14B2YH83ZXMPP  B00JBIVXGC  ...     1405814400  07 20, 2014
# 10257   A1RPTVW5VEOSI  B00JBIVXGC  ...     1404259200   07 2, 2014
#
# [6938 rows x 9 columns]

# %%
amazon_data[(amazon_data.reviewerID == "A2IBPI20UZIR0U")& (amazon_data.asin == "1384719342")].reviewerName
# Out:
# 0    cassandra tu "Yeah, well, that's just like, u...
# Name: reviewerName, dtype: object

# %%
type(amazon_data.reviewTime.values[0])
# Out:
# str

# %%
amazon_data.dropna()
# Out:
#            reviewerID        asin  ... unixReviewTime   reviewTime
# 0      A2IBPI20UZIR0U  1384719342  ...     1393545600  02 28, 2014
# 1      A14VAT5EAX3D9S  1384719342  ...     1363392000  03 16, 2013
# 2      A195EZSQDW3E21  1384719342  ...     1377648000  08 28, 2013
# 3      A2C00NNG1ZQQG2  1384719342  ...     1392336000  02 14, 2014
# 4       A94QU4C90B1AX  1384719342  ...     1392940800  02 21, 2014
# ...               ...         ...  ...            ...          ...
# 10256  A14B2YH83ZXMPP  B00JBIVXGC  ...     1405814400  07 20, 2014
# 10257   A1RPTVW5VEOSI  B00JBIVXGC  ...     1404259200   07 2, 2014
# 10258   AWCJ12KBO5VII  B00JBIVXGC  ...     1405987200  07 22, 2014
# 10259  A2Z7S8B5U4PAKJ  B00JBIVXGC  ...     1404172800   07 1, 2014
# 10260  A2WA8TDCTGUADI  B00JBIVXGC  ...     1405468800  07 16, 2014
#
# [10227 rows x 9 columns]
